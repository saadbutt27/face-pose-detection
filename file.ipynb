# %%
# %pip install opencv-python mediapipe ultralytics
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import mediapipe as mp

# Load YOLO model
model = YOLO("yolov8n.pt")  # Use a face-trained model if you have one

# Initialize webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Cannot open webcam.")
    exit()

# Initialize MediaPipe Face Mesh
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
                                  max_num_faces=1,
                                  refine_landmarks=True,
                                  min_detection_confidence=0.5,
                                  min_tracking_confidence=0.5)

def get_head_pose(image, landmarks):
    image_points = np.array([
        landmarks[1],    # Nose tip
        landmarks[152],  # Chin
        landmarks[263],  # Right eye right corner
        landmarks[33],   # Left eye left corner
        landmarks[287],  # Right mouth corner
        landmarks[57]    # Left mouth corner
    ], dtype="double")

    model_points = np.array([
        (0.0, 0.0, 0.0),             # Nose tip
        (0.0, -330.0, -65.0),        # Chin
        (225.0, 170.0, -135.0),      # Right eye
        (-225.0, 170.0, -135.0),     # Left eye
        (150.0, -150.0, -125.0),     # Right mouth
        (-150.0, -150.0, -125.0)     # Left mouth
    ])

    focal_length = image.shape[1]
    center = (image.shape[1] / 2, image.shape[0] / 2)
    camera_matrix = np.array([
        [focal_length, 0, center[0]],
        [0, focal_length, center[1]],
        [0, 0, 1]
    ], dtype="double")

    dist_coeffs = np.zeros((4, 1))
    success, rvec, _, _ = cv2.solvePnPRansac(
        model_points, image_points, camera_matrix, dist_coeffs)

    rmat, _ = cv2.Rodrigues(rvec)
    proj_matrix = np.hstack((rmat, np.zeros((3, 1))))
    _, _, _, _, _, _, angles = cv2.decomposeProjectionMatrix(proj_matrix)

    return angles  # pitch, yaw, roll

def get_eye_direction(landmarks, iw):
    left_eye = landmarks[33]
    right_eye = landmarks[263]
    eye_mid_x = (left_eye[0] + right_eye[0]) / 2
    eye_mid_x_norm = eye_mid_x / iw  # Normalize to 0-1 range

    if eye_mid_x_norm < 0.4:
        return "Looking Left"
    elif eye_mid_x_norm > 0.6:
        return "Looking Right"
    else:
        return "Looking Center"


print("Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model(frame)

    for box in results[0].boxes.xyxy:
        x1, y1, x2, y2 = map(int, box)
        face = frame[y1:y2, x1:x2]

        if face.shape[0] == 0 or face.shape[1] == 0:
            continue

        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        result_mesh = face_mesh.process(face_rgb)

        if result_mesh.multi_face_landmarks:
            for landmarks in result_mesh.multi_face_landmarks:
                ih, iw, _ = face.shape
                coords = [(int(p.x * iw), int(p.y * ih)) for p in landmarks.landmark]

                # Head pose estimation
                try:
                    angles = get_head_pose(face, coords)
                    pitch, yaw, roll = [a[0] for a in angles]
                    if abs(yaw) > 20:
                        cheat = "⚠️ Head turned!"
                        print(f"Yaw: {yaw} - Cheat: {cheat} Head truned")
                    elif abs(pitch) > 20:
                        cheat = "⚠️ Looking up/down!"
                        print(f"Pitch: {pitch} - Cheat: {cheat} Looking up/down")
                    else:
                        cheat = ""
                except:
                    cheat = "Head Pose Error"
                    print("Head Pose Error")

                # Eye direction
                # eye_dir = get_eye_direction(coords)
                eye_dir = get_eye_direction(coords, iw)
                if eye_dir != "Looking Center":
                    cheat = f"⚠️ {eye_dir}"
                    print(f"Eye Direction: {eye_dir} - Cheat: {cheat}")
                else:
                    cheat = ""
                    print("Eye Direction: Looking Center")

                # Draw box and alert
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, eye_dir, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
                if cheat:
                    cv2.putText(frame, cheat, (x1, y2 + 20),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    cv2.imshow("YOLO + MediaPipe Cheat Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit.
#
# 0: 480x640 (no detections), 681.1ms
# Speed: 13.2ms preprocess, 681.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 387.1ms
# Speed: 6.3ms preprocess, 387.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 357.4ms
# Speed: 6.7ms preprocess, 357.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -172.83182950311584 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 316.2ms
# Speed: 5.4ms preprocess, 316.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 334.9ms
# Speed: 7.1ms preprocess, 334.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 318.2ms
# Speed: 7.3ms preprocess, 318.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 331.2ms
# Speed: 7.9ms preprocess, 331.2ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -173.62842481219042 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 317.6ms
# Speed: 5.9ms preprocess, 317.6ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -169.6340040516753 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 344.0ms
# Speed: 6.9ms preprocess, 344.0ms inference, 10.4ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -174.64523419680893 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 374.1ms
# Speed: 5.9ms preprocess, 374.1ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -169.2443798683474 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 340.9ms
# Speed: 7.6ms preprocess, 340.9ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 354.2ms
# Speed: 8.8ms preprocess, 354.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 335.4ms
# Speed: 6.0ms preprocess, 335.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 369.1ms
# Speed: 6.5ms preprocess, 369.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 332.9ms
# Speed: 5.9ms preprocess, 332.9ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -173.9073895881062 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 336.9ms
# Speed: 5.8ms preprocess, 336.9ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 339.3ms
# Speed: 7.8ms preprocess, 339.3ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 336.1ms
# Speed: 8.4ms preprocess, 336.1ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 317.3ms
# Speed: 6.6ms preprocess, 317.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -174.9487788747264 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 1 person, 330.4ms
# Speed: 5.7ms preprocess, 330.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 319.9ms
# Speed: 5.3ms preprocess, 319.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -28.22722220230793 - Cheat: ⚠️ Head turned! Head truned
# Eye Direction: Looking Center
# Yaw: -23.171110668543427 - Cheat: ⚠️ Head turned! Head truned
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 2 persons, 343.0ms
# Speed: 7.0ms preprocess, 343.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -171.6201569461669 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 341.1ms
# Speed: 9.3ms preprocess, 341.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 321.5ms
# Speed: 6.7ms preprocess, 321.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 349.6ms
# Speed: 5.2ms preprocess, 349.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 333.8ms
# Speed: 6.6ms preprocess, 333.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 321.2ms
# Speed: 5.1ms preprocess, 321.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -160.4070439523186 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 335.1ms
# Speed: 8.1ms preprocess, 335.1ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -174.49962842539685 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 331.9ms
# Speed: 5.6ms preprocess, 331.9ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -175.11936291443314 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 328.9ms
# Speed: 5.4ms preprocess, 328.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 312.7ms
# Speed: 7.1ms preprocess, 312.7ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 299.8ms
# Speed: 5.9ms preprocess, 299.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -171.92994559090062 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 320.8ms
# Speed: 6.3ms preprocess, 320.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 309.7ms
# Speed: 6.2ms preprocess, 309.7ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 325.4ms
# Speed: 6.0ms preprocess, 325.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -171.86621145669793 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 322.2ms
# Speed: 6.0ms preprocess, 322.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -176.26997125471544 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 319.6ms
# Speed: 5.7ms preprocess, 319.6ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -173.06225065619606 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 319.3ms
# Speed: 5.7ms preprocess, 319.3ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 309.7ms
# Speed: 6.6ms preprocess, 309.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 309.6ms
# Speed: 7.3ms preprocess, 309.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 323.5ms
# Speed: 5.7ms preprocess, 323.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 310.4ms
# Speed: 5.8ms preprocess, 310.4ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -178.7496003743956 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 323.9ms
# Speed: 5.7ms preprocess, 323.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 320.5ms
# Speed: 6.3ms preprocess, 320.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 323.9ms
# Speed: 6.7ms preprocess, 323.9ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -169.2414138327361 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 345.0ms
# Speed: 7.8ms preprocess, 345.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 321.9ms
# Speed: 7.8ms preprocess, 321.9ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -169.53847397742368 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 331.3ms
# Speed: 5.5ms preprocess, 331.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 337.2ms
# Speed: 5.1ms preprocess, 337.2ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -173.52776759103975 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 327.9ms
# Speed: 6.4ms preprocess, 327.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -172.05051936625102 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 324.3ms
# Speed: 8.6ms preprocess, 324.3ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -172.7938731965182 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 313.8ms
# Speed: 5.7ms preprocess, 313.8ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -177.73050922077874 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
# Pitch: -175.11506564047647 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 315.1ms
# Speed: 6.2ms preprocess, 315.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -175.32459485787328 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 327.2ms
# Speed: 7.5ms preprocess, 327.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -173.9563326770083 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 313.7ms
# Speed: 6.3ms preprocess, 313.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 313.7ms
# Speed: 7.4ms preprocess, 313.7ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -175.9734551082291 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 315.5ms
# Speed: 8.2ms preprocess, 315.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -174.16577720470204 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 324.4ms
# Speed: 5.6ms preprocess, 324.4ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: 152.12519403464594 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 345.6ms
# Speed: 7.8ms preprocess, 345.6ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -171.30479013789974 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 (no detections), 338.0ms
# Speed: 6.8ms preprocess, 338.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 318.6ms
# Speed: 6.1ms preprocess, 318.6ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -31.483365510607683 - Cheat: ⚠️ Head turned! Head truned
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 338.7ms
# Speed: 7.1ms preprocess, 338.7ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 325.1ms
# Speed: 6.7ms preprocess, 325.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 312.6ms
# Speed: 9.3ms preprocess, 312.6ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 334.3ms
# Speed: 6.1ms preprocess, 334.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 316.2ms
# Speed: 5.7ms preprocess, 316.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 346.3ms
# Speed: 7.5ms preprocess, 346.3ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 327.4ms
# Speed: 7.4ms preprocess, 327.4ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 331.8ms
# Speed: 7.0ms preprocess, 331.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 341.3ms
# Speed: 6.5ms preprocess, 341.3ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -171.26274147825856 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 333.6ms
# Speed: 7.5ms preprocess, 333.6ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: 150.50293344338914 - Cheat: ⚠️ Looking up/down! Looking up/down
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 318.2ms
# Speed: 7.0ms preprocess, 318.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 345.7ms
# Speed: 7.3ms preprocess, 345.7ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
